# %%
# read the data
import numpy as np

# %%
# read the data
fp = r"spetrum.txt"
data = np.loadtxt(fp)

# %%
ww = list()
sp = list()
for sub in data:
    ww.append(sub[0])
    sp.append(sub[1])

# %%
# plot the data
from matplotlib import pyplot as plt
plt.plot(ww, sp, 'r')
plt.show()

# %%
plt.plot(ww, sp, 'r')
plt.show()

# %%
sp1 = sp.copy()

# %%
# let's remove the noise
# remove the two biggest and smallest values in sp
len_sp = len(sp)

# remove the two biggest
# find the peak value
peak1 = max(sp1)
sp1.remove(peak1)

peak2 = max(sp1)
sp1.remove(peak2)

# remove the smallest
sp1.remove(min(sp1))
sp1.remove(min(sp1))
print('The length of sp1',len(sp1))
print('The peak1 is ', peak1)
print('The peak2 is ', peak2)
# Out:
# The length of sp1 45
# The peak1 is  8.1089
# The peak2 is  6.9936

# %%
sp_remove = sp1

# calculate the mean
sp_mean = np.mean(sp_remove)
sp_mean
# Out:
# 0.28903111111111107

# %%
peak1_ind = sp.index(peak1)
peak2_ind = sp.index(peak2)

sp[peak1_ind] = sp_mean
sp[peak2_ind] = sp_mean

# %%
# plot the noise
plt.plot(ww, sp, 'r')
plt.show()

# %%
sum_d = 0
for i in range(len(ww)-1):
    sum_d = (ww[i+1] - ww[i]) * sp[i+1] + sum_d

sum_d = sum_d + ww[0] * sp[0]
print(i)
print(sum_d)
# Out:
# 47
# 0.8811799102222223

# %%
import math

# %%
print("The standard deviation of the white noise is {0:.2f}" .format(math.sqrt(sum_d)))
# Out:
# The standard deviation of the white noise is 0.94

# %%
math.sqrt(sum_d)
# Out:
# 0.9387118355609576

# %%
sp2 = sp.copy()
sp2[:] = [x - sp_mean for x in sp2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-e963ea5c9af6> in <module>
# ----> 1 a=list(2,3,5,6)
#       2 a
#
# TypeError: list() takes at most 1 argument (4 given)

# %%
sp1 = sp.copy()

# %%
sp_remove = sp_remove.remove(max(sp.remove))
sp_remove = sp_remove.remove(min(sp.remove))
